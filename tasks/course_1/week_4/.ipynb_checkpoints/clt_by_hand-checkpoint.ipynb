# %% [markdown]
# # Центральная предельная теорема своими руками

# %% [markdown]
# ### Исследование распределения Парето

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pareto
from scipy.stats import norm
# %matplotlib inline

# %%
b = 2.62
samples = pareto.rvs(b, size = 1000)

# %%
plt.hist(samples, bins=150, normed=True, label='histogram')
plt.ylabel('number of samples')
plt.xlabel('$x$')

x = np.linspace(0,6,1000)
pdf = pareto.pdf(x, b)
plt.plot(x, pdf, label='theoretical pdf', alpha=1)
plt.legend()

# %% [markdown]
# ### Оценить распределение выборочного среднего случайной величины, заданной распределением Парето

# %% [markdown]
# #### 1.) Объем выбрки n = 5

# %%
n = 5

def calcParetoAverageSample(n):
    av_sample = []
    for i in range(0, 1000):
        samp = pareto.rvs(b, size=n)
        av = round(np.average(samp), 8)
        av_sample.append(av);
    return av_sample    

ex = b / (b - 1)
dx = np.power((1 / (b - 1)), 2) * (b / (b - 2))
dx_av = round(dx / n, 8)


plt.hist(calcParetoAverageSample(5), bins=150, normed=True)
plt.ylabel('number of av_samples')
plt.xlabel('$x$')   

x = np.linspace(0,8,100)
norm_dens = norm.pdf(x, ex, np.sqrt(dx_av))
plt.plot(x, norm_dens)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-c1f6598767f5> in <module>()
#      19
#      20 x = np.linspace(0,8,100)
# ---> 21 norm_dens = norm.pdf(x, ex, np.sqrt(dx_av))
#      22 plt.plot(x, norm_dens)
#
# NameError: name 'norm' is not defined

# %% [markdown]
# #### 2.) n = 10

# %%
n = 10
dx_av = round(dx / n, 8)
print dx_av

plt.hist(calcParetoAverageSample(10), bins=150, normed=True)
plt.ylabel('number of av_samples')
plt.xlabel('$x$')
# Out:
# 0.16101991

# %% [markdown]
# #### 3.) n = 50

# %%
n = 50
dx_av = round(dx / n, 8)
print 'dx_av =', dx_av

plt.hist(calcParetoAverageSample(n), bins=150, normed=True)
plt.ylabel('number of av_samples')
plt.xlabel('$x$')
# Out:
# dx_av = 0.03220398

# %% [markdown]
# #### 4.) n = 100

# %%
n = 100
dx_av = round(dx / n, 8)
print 'dx_av =', dx_av

plt.hist(calcParetoAverageSample(n), bins=150, normed=True)
plt.ylabel('number of av_samples')
plt.xlabel('$x$')
# Out:
# dx_av = 0.01610199

# %% [markdown]
# #### 5.) n=200

# %%
n = 200
dx_av = round(dx / n, 8)
print 'dx_av =', dx_av

plt.hist(calcParetoAverageSample(n), bins=150, normed=True)
plt.ylabel('number of av_samples')
plt.xlabel('$x$')
# Out:
# dx_av = 0.008051

# %% [markdown]
# #### 6.) n = 300

# %%
n = 300
dx_av = round(dx / n, 8)
print 'dx_av =', dx_av

plt.hist(calcParetoAverageSample(n), bins=150, normed=True)
plt.ylabel('number of av_samples')
plt.xlabel('$x$')
# Out:
# dx_av = 0.00536733

# %%
dx_av = dx /
# Out:
# ex = 1.61728395062
# dx = 1.61019907469
